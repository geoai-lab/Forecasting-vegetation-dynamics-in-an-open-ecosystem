# %%
import rasterio as ro
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import random
import math
import pandas
from scipy import optimize

#from keras_tuner.engine.hyperparameters import HyperParameters

from scipy.signal import savgol_filter

# %%
# load the data
ndvi = ro.open("Data/NDVI.grd")

covariates = ro.open("Data/covariates_250m_peninsula.grd")

p1 = ro.open("Data/newprec_01.tif")

p7 = ro.open("Data/newprec_07.tif")

fire_history = ro.open("Data/age.grd")

qa_data = ro.open("Data/QA.grd")

# %%
# read the shape of covariates
covariates_arr = covariates.read()

np.shape(covariates_arr)
# Out:
# (12, 172, 63)

# %%
# read the shape of NDVI
ndvi_arr = ndvi.read()

np.shape(ndvi_arr)
# Out:
# (748, 172, 63)

# %%
# read the shape of QA
qa_arr = qa_data.read()

np.shape(qa_arr)
# Out:
# (748, 172, 63)

# %%
# read the shape of fire history
fire_arr = fire_history.read()
fire_arr.shape
# Out:
# (748, 172, 63)

# %%
fire_arr[0]
# Out:
# array([[   nan,    nan,    nan, ...,    nan,    nan,    nan],
#        [   nan,    nan,    nan, ...,    nan,    nan,    nan],
#        [   nan,    nan,    nan, ...,    nan,    nan,    nan],
#        ...,
#        [   nan,    nan,    nan, ...,  2784.,  2784., 14658.],
#        [   nan,    nan,    nan, ...,  2784.,  2784., 14658.],
#        [   nan,    nan,    nan, ..., 14658., 14658., 14658.]],
#       dtype=float32)

# %%
# read the precipitation data
p1_arr = p1.read()
p1_arr.shape
p7_arr = p7.read()
p7_arr.shape

p1_arr = p1_arr[:,:172,:63]

p7_arr = p7_arr[:,:172,:63]

# %%
p1_arr[p1_arr<0] = np.nan 
p7_arr[p7_arr<0] = np.nan

# %%
# replace the precipitation value
covariates_arr[9] = p1_arr
covariates_arr[10] = p7_arr

# %%
# Visualize the environment covariates
plt.figure(figsize=(15,12))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.title(covariates.descriptions[i])
    plt.imshow(covariates_arr[i])
    plt.axis('off')

# %%
# read the shape of new covariates 
np.shape(covariates_arr)
# Out:
# (12, 172, 63)

# %%
# What is the value range of the environmental variables?
for i in range(covariates_arr.shape[0]):
    layer_name = covariates.descriptions[i]
    min_value = np.nanmin(covariates_arr[i])
    max_value = np.nanmax(covariates_arr[i])
    mean_value = np.nanmean(covariates_arr[i])
    print(layer_name+": min: "+str(min_value)+", max: "+str(max_value)+", mean: "+str(mean_value)+"\n")
# Out:
# aspect: min: 0.025960453, max: 6.2611136, mean: 3.0046475
#
# dem: min: -1.2942011, max: 1069.7134, mean: 172.9334
#
# janrad: min: 4004.0354, max: 9311.947, mean: 8741.644
#
# julrad: min: 471.11484, max: 6528.9673, mean: 3281.7493
#
# slope: min: 6.7596327e-22, max: 1.2136732, mean: 0.2010844
#
# tmaxjan: min: 21.831682, max: 31.777122, mean: 28.34501
#
# tminjul: min: 3.6588407, max: 11.716162, mean: 9.477635
#
# tpi: min: -25.07602, max: 42.91772, mean: 0.050585095
#
# tri: min: 1.2236242e-19, max: 244.41881, mean: 17.412844
#
# prec1: min: 16.0, max: 32.981983, mean: 22.70195
#
# prec7: min: 80.15998, max: 169.64435, mean: 117.04249
#
# vegtype: min: 2.0, max: 20.0, mean: 14.957029

# %%
def MaxMinNormalization(x, norm_min, norm_max):
    """（0,1] normaliaztion"""
    x = (x - norm_min) / (norm_max - norm_min)
    return x

# %%
# normalize the covariate data
norm_covariates = np.zeros(covariates_arr.shape)
for i in range(12):
    norm_covariates[i] = MaxMinNormalization(covariates_arr[i],np.nanmin(covariates_arr[i])-1,np.nanmax(covariates_arr[i])+1)
print(norm_covariates.shape)
# Out:
# (12, 172, 63)

# %%
# normalize the fire history data
norm_fire = np.zeros(fire_arr.shape)
for i in range(748):
    norm_fire[i] = MaxMinNormalization(fire_arr[i],np.nanmin(fire_arr[i])-1,np.nanmax(fire_arr[i])+7300)
print(norm_fire.shape)
# Out:
# (748, 172, 63)

# %%
norm_fire[0]
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ..., 0.12615076, 0.12615076,
#         0.66730469],
#        [       nan,        nan,        nan, ..., 0.12615076, 0.12615076,
#         0.66730469],
#        [       nan,        nan,        nan, ..., 0.66730469, 0.66730469,
#         0.66730469]])

# %%
# What is the value range of the NORMALIZED environmental variables?
for i in range(norm_covariates.shape[0]):
    layer_name = covariates.descriptions[i]
    min_value = np.nanmin(norm_covariates[i])
    max_value = np.nanmax(norm_covariates[i])
    mean_value = np.nanmean(norm_covariates[i])
    print(layer_name+": min: "+str(min_value)+", max: "+str(max_value)+", mean: "+str(mean_value)+"\n")
# Out:
# aspect: min: 0.1214306503534317, max: 0.8785693645477295, mean: 0.48313456580264563
#
# dem: min: 0.0009319598902948201, max: 0.999068021774292, mean: 0.16330510320843938
#
# janrad: min: 0.00018832703062798828, max: 0.9998116493225098, mean: 0.8924082571804849
#
# julrad: min: 0.00016502052312716842, max: 0.9998349547386169, mean: 0.4639774106588817
#
# slope: min: 0.31117042899131775, max: 0.6888296008110046, mean: 0.3737419339288029
#
# tmaxjan: min: 0.08371394872665405, max: 0.916286051273346, mean: 0.6289705463014474
#
# tminjul: min: 0.09943005442619324, max: 0.9005699753761292, mean: 0.6779932413030669
#
# tpi: min: 0.014286991208791733, max: 0.985713005065918, mean: 0.37327056577691187
#
# tri: min: 0.0040581319481134415, max: 0.9959418773651123, mean: 0.07472174343360968
#
# prec1: min: 0.052681535482406616, max: 0.9473184943199158, mean: 0.40575049582622397
#
# prec7: min: 0.010930829681456089, max: 0.9890691637992859, mean: 0.4140873334682927
#
# vegtype: min: 0.05000000074505806, max: 0.949999988079071, mean: 0.6978514697602813

# %%
# Visualize the NORMALIZED environment covariates
plt.figure(figsize=(15,12))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.title(covariates.descriptions[i])
    plt.imshow(norm_covariates[i])
    plt.axis('off')

# %%
# create a mask based on the environmental variables and fire history
study_region_mask = np.zeros((ndvi.height,ndvi.width))


for i in range(study_region_mask.shape[0]):
    for j in range(study_region_mask.shape[1]):
        found_nan = False
        for var_index in range(covariates_arr.shape[0]):
            if np.isnan(covariates_arr[var_index,i,j]):
                found_nan =True
                break

        for time_step in range(fire_arr.shape[0]):
            if np.isnan(fire_arr[time_step,i,j]):
                found_nan =True
                break
        
        if found_nan:
            study_region_mask[i,j] = -1
        else:
            study_region_mask[i,j] = 1

plt.imshow(study_region_mask)

# %%
nan_value = 0

# %%
# a mask out function
def mask_layer(input_layer, mask_layer):
    # for i in range(mask_layer.shape[0]):
    #     for j in range(mask_layer.shape[1]):
    #         if mask_layer[i,j]==-1:
    #             input_layer[i,j] = nan_value # replace the nan value in the input data
    input_layer[mask_layer==-1] = nan_value

    return input_layer

# %%
#savgol_filter to smooth the data
#ndvi_times = range(1,ndvi.count+1)

qa_value_array = qa_data.read()

#ndvi_smoothed = []
smoothed_dataset = np.zeros((ndvi.count,ndvi.height,ndvi.width))

for m in range(0,ndvi.height):
  for n in range(0,ndvi.width):

    ndvi_ori = ndvi_arr[:,m,n]
    
    if study_region_mask[m,n] ==-1:
      #ndvi_smoothed.append(ndvi_ori)
      smoothed_dataset[:,m,n] = ndvi_ori
      continue
    
    
    qa_value = qa_arr[:,m,n]
    # for i in ndvi_times:
    #   ndvi_data = ndvi.read(i)
    #   ndvi_pixel = ndvi_data[m,n]
    #   ndvi_ori.append(ndvi_pixel) #将每个像素上所有时间点上的值存入数组


    #   qa = qa_data.read(i)
    #   qa_pixel = qa[m,n]
    #   qa_value.append(qa_pixel) #将每个像素上所有时间点上的QA值存入数组

    smoothed = savgol_filter(ndvi_ori,7,2)

    for t in range(qa_value.shape[0]):
      if qa_value[t] == 0 and ndvi_ori[t]>0:
        smoothed[t] = ndvi_ori[t]
      # else:
      #   pass

    #ndvi_smoothed.append(smoothed)
    smoothed_dataset[:,m,n] = smoothed


#ndvi_smoothed = np.asarray(ndvi_smoothed)

# %%
#np.shape(ndvi_smoothed)

# %%
# created the dataset contains ONLY SMOOTHED NDVI DATA
# smoothed_dataset = np.zeros((ndvi.count,ndvi.height,ndvi.width))
# for time_steps in range(0,ndvi.count):
#   for m in range(0,ndvi.height):
#     for n in range(0,ndvi.width):
#       smoothed_dataset[time_steps,m,n] = ndvi_smoothed[63*m+n][time_steps]

print(np.shape(smoothed_dataset))
# Out:
# (748, 172, 63)

# %%
# visualize random 12 NDVI values of SMOOTHED NDVI DATASET
plt.figure(figsize=(15,12))
for i in range(1,13):
    plt.subplot(3,4,i)
    random_time = random.randint(0,ndvi.count-1)
    plt.imshow(smoothed_dataset[random_time,:,:])
    plt.axis('off')

# %%
# create multi_input dataset
norm_smoothed_dataset = np.zeros((ndvi.count,ndvi.height,ndvi.width,13))

for time_steps in range(0,ndvi.count):
    norm_smoothed_dataset[time_steps,:,:,0] = smoothed_dataset[time_steps,:,:] #NDVI

    norm_smoothed_dataset[time_steps,:,:,1] = norm_covariates[0,:,:] # aspect
    norm_smoothed_dataset[time_steps,:,:,2] = norm_covariates[1,:,:] # DEM
    norm_smoothed_dataset[time_steps,:,:,3] = norm_covariates[2,:,:] # janrad
    norm_smoothed_dataset[time_steps,:,:,4] = norm_covariates[3,:,:] # julrad
    #norm_smoothed_dataset[time_steps,:,:,4] = norm_covariates[4,:,:] # slope
    norm_smoothed_dataset[time_steps,:,:,5] = norm_covariates[5,:,:] # tmaxjan
    norm_smoothed_dataset[time_steps,:,:,6] = norm_covariates[6,:,:] # tmaxjul
    norm_smoothed_dataset[time_steps,:,:,7] = norm_covariates[7,:,:] # tpi
    norm_smoothed_dataset[time_steps,:,:,8] = norm_covariates[8,:,:] # tri
    norm_smoothed_dataset[time_steps,:,:,9] = norm_covariates[9,:,:] # prec1
    norm_smoothed_dataset[time_steps,:,:,10] = norm_covariates[10,:,:] # prec7
    norm_smoothed_dataset[time_steps,:,:,11] = norm_covariates[11,:,:] # vegtype
 
    norm_smoothed_dataset[time_steps,:,:,12] = norm_fire[time_steps,:,:]               


print(norm_smoothed_dataset.shape)
# Out:
# (748, 172, 63, 13)

# %%
# What is the value range of the NORMALIZED SMOOTHED dataset before the mask
for i in range(1,12):
    layer_name = int(i)
    min_value = np.nanmin(norm_smoothed_dataset[:,:,:,i])
    max_value = np.nanmax(norm_smoothed_dataset[:,:,:,i])
    mean_value = np.nanmean(norm_smoothed_dataset[:,:,:,i])
    print(str(layer_name)+": min: "+str(min_value)+", max: "+str(max_value)+", mean: "+str(mean_value)+"\n")
# Out:
# 1: min: 0.1214306503534317, max: 0.8785693645477295, mean: 0.48313456580264563
#
# 2: min: 0.0009319598902948201, max: 0.999068021774292, mean: 0.16330510320844016
#
# 3: min: 0.00018832703062798828, max: 0.9998116493225098, mean: 0.8924082571804762
#
# 4: min: 0.00016502052312716842, max: 0.9998349547386169, mean: 0.46397741065888853
#
# 5: min: 0.08371394872665405, max: 0.916286051273346, mean: 0.6289705463014474
#
# 6: min: 0.09943005442619324, max: 0.9005699753761292, mean: 0.6779932413030669
#
# 7: min: 0.014286991208791733, max: 0.985713005065918, mean: 0.37327056577691187
#
# 8: min: 0.0040581319481134415, max: 0.9959418773651123, mean: 0.07472174343360968
#
# 9: min: 0.052681535482406616, max: 0.9473184943199158, mean: 0.40575049582622397
#
# 10: min: 0.010930829681456089, max: 0.9890691637992859, mean: 0.4140873334682927
#
# 11: min: 0.05000000074505806, max: 0.949999988079071, mean: 0.6978514697602813

# %%
# filter the multi_input dataset with the mask
for time_steps in range(0,norm_smoothed_dataset.shape[0]):
    norm_smoothed_dataset[time_steps,:,:,:] = mask_layer(norm_smoothed_dataset[time_steps,:,:,:],study_region_mask)

print(norm_smoothed_dataset.shape)
# Out:
# (748, 172, 63, 13)

# %%
# Visualize the NORMALIZED and masked variables
plt.figure(figsize=(15,12))
figure_names = ["NDVI"]
for i in range(11):
    figure_names.append(covariates.descriptions[i+1])
figure_names.append("Fire age")

for i in range(13):
    plt.subplot(4,4,i+1)
    #plt.title(figure_names[i])
    plt.imshow(norm_smoothed_dataset[0,:,:,i])
    plt.axis('off')

# %%
# What is the value range of the NORMALIZED SMOOTHED dataset after the mask
for i in range(1,12):
    layer_name = int(i)
    min_value = np.nanmin(norm_smoothed_dataset[:,:,:,i])
    max_value = np.nanmax(norm_smoothed_dataset[:,:,:,i])
    mean_value = np.nanmean(norm_smoothed_dataset[:,:,:,i])
    print(str(layer_name)+": min: "+str(min_value)+", max: "+str(max_value)+", mean: "+str(mean_value)+"\n")
# Out:
# 1: min: 0.0, max: 0.8766118288040161, mean: 0.1871742860126337
#
# 2: min: 0.0, max: 0.999068021774292, mean: 0.0878697360836163
#
# 3: min: 0.0, max: 0.9998116493225098, mean: 0.3309629230098933
#
# 4: min: 0.0, max: 0.9998349547386169, mean: 0.1728341373142324
#
# 5: min: 0.0, max: 0.9015579223632812, mean: 0.22608281924479032
#
# 6: min: 0.0, max: 0.8692363500595093, mean: 0.24528126100173797
#
# 7: min: 0.0, max: 0.6976239681243896, mean: 0.14182202577745304
#
# 8: min: 0.0, max: 0.9333016872406006, mean: 0.03708200562367509
#
# 9: min: 0.0, max: 0.9473184943199158, mean: 0.16720470398404572
#
# 10: min: 0.0, max: 0.9890691637992859, mean: 0.17955702709961627
#
# 11: min: 0.0, max: 0.949999988079071, mean: 0.26781099983558043

# %%
min_value = np.nanmin(norm_smoothed_dataset[:,:,:,0])
max_value = np.nanmax(norm_smoothed_dataset[:,:,:,0])

print(min_value)
print(max_value)
# Out:
# -0.164983332157135
# 1.0152380466461182

# %%
min_value = np.nanmin(norm_smoothed_dataset[:,:,:,12])
max_value = np.nanmax(norm_smoothed_dataset[:,:,:,12])

print(min_value)
print(max_value)
# Out:
# 0.0
# 0.7381447553634644

# %% [markdown]
# convLSTM part

# %%
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
tf.random.set_seed(42)

# %%
step_ahead = 23

# %%
def create_model():
    tf.random.set_seed(42)

    convLSTM_model = keras.Sequential(
        [
            #keras.Input(shape=(None, 172, 63, 1)),  # Variable-length sequence of 172x63x1 frames
            layers.InputLayer(input_shape=(None, ndvi.height, ndvi.width, 13)),
            layers.ConvLSTM2D(filters=40, kernel_size=(3, 3), padding="same", return_sequences=True),
            #layers.BatchNormalization(),
            layers.ConvLSTM2D(filters=40, kernel_size=(3, 3), padding="same", return_sequences=True),
            #layers.BatchNormalization(),
            layers.ConvLSTM2D(filters=20, kernel_size=(3, 3), padding="same", return_sequences=True),
            #layers.BatchNormalization(),
            layers.ConvLSTM2D(filters=10, kernel_size=(3, 3), padding="same", return_sequences=True),
            #layers.BatchNormalization(),
            layers.Conv3D(filters=step_ahead, kernel_size=(3, 3, 3), padding="same", activation="linear")
        ]
    )
    convLSTM_model.compile(loss=keras.losses.mean_squared_error, optimizer=keras.optimizers.Adam())
    return convLSTM_model

# %%
# Generate training data
# So we are going to use 75% of the data for training and 25% for testing
# step length is 15
"""
training_size = int(ndvi.count * 0.75) # 561

initial_ndvi = []
next_ndvi = []

#next_ndvi = np.empty((training_size-15,15,172,63,step_ahead))

for sample_i in range(0,training_size-15):
    #initial_index = random.randint(1,(training_size-16))
    
    this_initial_sequence = []
    this_next_sequence = []
    b = []
    for t in range(0,15): # each sample has 15 time steps
        #this_initial = ndvi.read(initial_index + t)
        this_initial = norm_smoothed_dataset[sample_i + t,:,:,:]
        #this_initial = this_initial[..., np.newaxis]
        this_initial_sequence.append(this_initial)
        
        #this_next = ndvi.read(initial_index + t +1)
        #this_next = norm_smoothed_dataset[sample_i + t + 1,:,:,0] #original code
        #this_next = ndvi.read(initial_index + t +1)
        #for j in range(step_ahead):
            #this_next = norm_smoothed_dataset[sample_i + t + step_ahead,:,:,0]
            #this_next = this_next[..., np.newaxis]
            #this_next_step_ahead.append(this_next)
        a = []
        #this_next_sequence.append(this_next_step_ahead)
        for j in range(1,step_ahead+1):
            next_value = norm_smoothed_dataset[sample_i+t+j,:,:,0]
            a.append(next_value)
        b.append(a)

    initial_ndvi.append(this_initial_sequence)
    #next_ndvi.append(this_next_sequence)
    next_ndvi.append(b)

initial_ndvi = np.asarray(initial_ndvi)
next_ndvi = np.asarray(next_ndvi)
next_ndvi = next_ndvi.reshape((training_size-15,15,172,63,step_ahead))
"""
# Out:
# '\ntraining_size = int(ndvi.count * 0.75) # 561\n\ninitial_ndvi = []\nnext_ndvi = []\n\n#next_ndvi = np.empty((training_size-15,15,172,63,step_ahead))\n\nfor sample_i in range(0,training_size-15):\n    #initial_index = random.randint(1,(training_size-16))\n    \n    this_initial_sequence = []\n    this_next_sequence = []\n    b = []\n    for t in range(0,15): # each sample has 15 time steps\n        #this_initial = ndvi.read(initial_index + t)\n        this_initial = norm_smoothed_dataset[sample_i + t,:,:,:]\n        #this_initial = this_initial[..., np.newaxis]\n        this_initial_sequence.append(this_initial)\n        \n        #this_next = ndvi.read(initial_index + t +1)\n        #this_next = norm_smoothed_dataset[sample_i + t + 1,:,:,0] #original code\n        #this_next = ndvi.read(initial_index + t +1)\n        #for j in range(step_ahead):\n            #this_next = norm_smoothed_dataset[sample_i + t + step_ahead,:,:,0]\n            #this_next = this_next[..., np.newaxis]\n            #this_next_step_ahead.append(this_next)\n        a = []\n        #this_next_sequence.append(this_next_step_ahead)\n        for j in range(1,step_ahead+1):\n            next_value = norm_smoothed_dataset[sample_i+t+j,:,:,0]\n            a.append(next_value)\n        b.append(a)\n\n    initial_ndvi.append(this_initial_sequence)\n    #next_ndvi.append(this_next_sequence)\n    next_ndvi.append(b)\n\ninitial_ndvi = np.asarray(initial_ndvi)\nnext_ndvi = np.asarray(next_ndvi)\nnext_ndvi = next_ndvi.reshape((training_size-15,15,172,63,step_ahead))\n'

# %%
series = []
for i in range(0,ndvi.count-15-step_ahead+1):
    this_series_arr = []
    for j in range(0,15+step_ahead):
        this_series = norm_smoothed_dataset[i+j,:,:,:]
        this_series_arr.append(this_series)

    series.append(this_series_arr)

series = np.asarray(series)

print(series.shape)

Y = np.empty((series.shape[0],15,172,63,step_ahead))

for k in range(1, step_ahead + 1):
    Y[:,:,:,:, k - 1] = series[:, k:k + 15,:,:, 0]

X = series[:,:15,:,:,:]

training_size = int(0.75*series.shape[0]) # 561

initial_ndvi = X[:training_size,...]
next_ndvi = Y[:training_size,...]

test_data_input = X[training_size:,...]
test_data_label = Y[training_size:,...]
# Out:
# (711, 38, 172, 63, 13)

# %%
initial_ndvi.shape
# Out:
# (533, 15, 172, 63, 13)

# %%
next_ndvi.shape
# Out:
# (533, 15, 172, 63, 23)

# %%
def x_generator():
    for i in range(initial_ndvi.shape[0]):
        yield initial_ndvi[i]

# %%
def y_generator():
    for i in range(next_ndvi.shape[0]):
        yield next_ndvi[i]

# %%
x_dataset = tf.data.Dataset.from_generator(x_generator,output_types=tf.float32)

# %%
y_dataset = tf.data.Dataset.from_generator(y_generator,output_types=tf.float32)

# %%
combine_dataset = tf.data.Dataset.zip((x_dataset, y_dataset))

# %%
combine_batches = combine_dataset.batch(100)

# %%
for x,y in combine_batches.take(6):
    print(np.shape([x_arr.numpy() for x_arr in x]))
    print(np.shape([y_arr.numpy() for y_arr in y]))
# Out:
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# (33, 15, 172, 63, 13)
# (33, 15, 172, 63, 23)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=10)
#Train the model
convLSTM_model = create_model()

epochs = 300 


for x,y in combine_batches.take(6):
    print(np.shape([x_arr.numpy() for x_arr in x]))
    print(np.shape([y_arr.numpy() for y_arr in y]))
    history = convLSTM_model.fit(
        np.asarray([x_arr.numpy() for x_arr in x]),
        np.asarray([y_arr.numpy() for y_arr in y]),
        batch_size=1,
        epochs=epochs,
        verbose=1,
        validation_split=0.1,
        callbacks=[callback]
    )


    loss_train = history.history["loss"]
    loss_val = history.history['val_loss']

    plt.plot(loss_train, 'g', label='loss')
    plt.plot(loss_val, 'b', label='validation loss')
    plt.title('Training and Validation loss')
    plt.ylim(0,0.03)
    plt.legend()
    plt.show()

convLSTM_model.save('PretrainedModel/ConvLSTM_smoothed_NDVI_23stepahead_all_without_slope_linearactivate_tfAPI.h5')
# Out:
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# Epoch 1/300
# 90/90 [==============================] - 181s 976ms/step - loss: 0.0228 - val_loss: 0.0104
# Epoch 2/300
# 90/90 [==============================] - 87s 968ms/step - loss: 0.0095 - val_loss: 0.0079
# Epoch 3/300
# 90/90 [==============================] - 87s 969ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 4/300
# 90/90 [==============================] - 87s 970ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 5/300
# 90/90 [==============================] - 87s 970ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 6/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 7/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 8/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 9/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 10/300
# 90/90 [==============================] - 87s 970ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 11/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 12/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 13/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 14/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 15/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 16/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 17/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 18/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 19/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 20/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 21/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 22/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 23/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 24/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 25/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 26/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 27/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 28/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 29/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 30/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 31/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 32/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 33/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 34/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 35/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 36/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 37/300
# 90/90 [==============================] - 87s 971ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 38/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 39/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 40/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 41/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 42/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 43/300
# 90/90 [==============================] - 87s 972ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 44/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 45/300
# 90/90 [==============================] - 88s 973ms/step - loss: 0.0026 - val_loss: 0.0026
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# Epoch 1/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 2/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 3/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 4/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 5/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 6/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 7/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 8/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 9/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 10/300
# 90/90 [==============================] - 88s 976ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 11/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 12/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 13/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 14/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 15/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 16/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 17/300
# 90/90 [==============================] - 88s 976ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 18/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 19/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 20/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 21/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 22/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 23/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 24/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 25/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 26/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 27/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 28/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 29/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 30/300
# 90/90 [==============================] - 88s 976ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 31/300
# 90/90 [==============================] - 88s 976ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 32/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 33/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 34/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 35/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 36/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 37/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 38/300
# 90/90 [==============================] - 88s 976ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 39/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 40/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 41/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 42/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 43/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 44/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 45/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 46/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 47/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 48/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 49/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 50/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 51/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 52/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 53/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 54/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 55/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0022
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# Epoch 1/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 2/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 3/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 4/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 5/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 6/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 7/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 8/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 9/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 10/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 11/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 12/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 13/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 14/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 15/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 16/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 17/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 18/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 19/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 20/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 21/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 22/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 23/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 24/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 25/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 26/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 27/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 28/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 29/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 30/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 31/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 32/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 33/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 34/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 35/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 36/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 37/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 38/300
# 90/90 [==============================] - 88s 980ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 39/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0027
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# Epoch 1/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 2/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 3/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 4/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 5/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 6/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 7/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 8/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 9/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 10/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 11/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 12/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 13/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 14/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 15/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 16/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 17/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 18/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 19/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 20/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 21/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 22/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 23/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 24/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 25/300
# 90/90 [==============================] - 88s 977ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 26/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 27/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 28/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 29/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 30/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 31/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 32/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0016 - val_loss: 0.0019
# (100, 15, 172, 63, 13)
# (100, 15, 172, 63, 23)
# Epoch 1/300
# 90/90 [==============================] - 88s 975ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 2/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 3/300
# 90/90 [==============================] - 88s 980ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 4/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 5/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 6/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 7/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 8/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 9/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 10/300
# 90/90 [==============================] - 88s 978ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 11/300
# 90/90 [==============================] - 88s 979ms/step - loss: 0.0016 - val_loss: 0.0021
# (33, 15, 172, 63, 13)
# (33, 15, 172, 63, 23)
# Epoch 1/300
# 29/29 [==============================] - 29s 990ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 2/300
# 29/29 [==============================] - 29s 987ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 3/300
# 29/29 [==============================] - 29s 989ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 4/300
# 29/29 [==============================] - 29s 986ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 5/300
# 29/29 [==============================] - 29s 986ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 6/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 7/300
# 29/29 [==============================] - 29s 989ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 8/300
# 29/29 [==============================] - 29s 990ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 9/300
# 29/29 [==============================] - 29s 986ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 10/300
# 29/29 [==============================] - 29s 990ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 11/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 12/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 13/300
# 29/29 [==============================] - 29s 989ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 14/300
# 29/29 [==============================] - 29s 987ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 15/300
# 29/29 [==============================] - 29s 990ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 16/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 17/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 18/300
# 29/29 [==============================] - 29s 988ms/step - loss: 0.0013 - val_loss: 0.0017

# %%
loss_train = history.history["loss"]
loss_val = history.history['val_loss']

plt.plot(loss_train, 'g', label='loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')

plt.ylim(0,0.0225)
plt.legend()
plt.show()

# %%
convLSTM_model = tf.keras.models.load_model('PretrainedModel/ConvLSTM_smoothed_NDVI_23stepahead_all_without_slope_linearactivate_tfAPI.h5')
convLSTM_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, None, 172, 63, 40) 76480
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, None, 172, 63, 40) 115360
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, None, 172, 63, 20) 43280
# _________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)  (None, None, 172, 63, 10) 10840
# _________________________________________________________________
# conv3d (Conv3D)              (None, None, 172, 63, 23) 6233
# =================================================================
# Total params: 252,193
# Trainable params: 252,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
# create test dataset using the remaining 25% data 
test_data_input = []
test_data_label = []


for sample_i in range(training_size, ndvi.count-step_ahead):
    test_lable_step_ahead = []
    for step_ahead_i in range(0,step_ahead):
        test_lable_step_ahead.append(norm_smoothed_dataset[sample_i+step_ahead_i,:,:,0])
    test_data_label.append(test_lable_step_ahead)
    this_initial_sequence = []
    for t in range(sample_i-15,sample_i): # each sample has 15 time steps
        this_initial = norm_smoothed_dataset[t,:,:,:]
        #this_initial = this_initial[..., np.newaxis]
        this_initial_sequence.append(this_initial)
        
    test_data_input.append(this_initial_sequence)
    
    
test_data_input = np.asarray(test_data_input)
test_data_label = np.asarray(test_data_label)
test_data_input = test_data_input.reshape((183,15,172,63,13))
test_data_label = test_data_label.reshape((183,172,63,step_ahead))
"""
# Out:
# '\n# create test dataset using the remaining 25% data \ntest_data_input = []\ntest_data_label = []\n\n\nfor sample_i in range(training_size, ndvi.count-step_ahead):\n    test_lable_step_ahead = []\n    for step_ahead_i in range(0,step_ahead):\n        test_lable_step_ahead.append(norm_smoothed_dataset[sample_i+step_ahead_i,:,:,0])\n    test_data_label.append(test_lable_step_ahead)\n    this_initial_sequence = []\n    for t in range(sample_i-15,sample_i): # each sample has 15 time steps\n        this_initial = norm_smoothed_dataset[t,:,:,:]\n        #this_initial = this_initial[..., np.newaxis]\n        this_initial_sequence.append(this_initial)\n        \n    test_data_input.append(this_initial_sequence)\n    \n    \ntest_data_input = np.asarray(test_data_input)\ntest_data_label = np.asarray(test_data_label)\ntest_data_input = test_data_input.reshape((183,15,172,63,13))\ntest_data_label = test_data_label.reshape((183,172,63,step_ahead))\n'

# %%
test_data_input.shape, test_data_label.shape
# Out:
# ((178, 15, 172, 63, 13), (178, 15, 172, 63, 23))

# %%
# Test the model performance based on the generated test data

predicted = convLSTM_model.predict(test_data_input) 
print(np.shape(predicted))

#predicted = predicted[::, -1, ::, ::, :]   
#print("the shape of predicted data is " + str(predicted.shape))
# Out:
# (178, 15, 172, 63, 23)

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
#from keras_tuner.engine.hyperparameters import HyperParameters
import sklearn
def evaluate_method_performance(labeled_data, predicted, n_training_time_steps):
    n_test_time_steps = labeled_data.shape[0]
    time_step_ahead = labeled_data.shape[3]
    
    valid_label = []
    valid_predicted = []
    
    for t in range(n_test_time_steps):
        for m in range(172):
            for n in range(63):
                for a in range(time_step_ahead):
                    if qa_arr[n_training_time_steps+t+a,m,n] == 0 and ndvi_arr[n_training_time_steps+t+a,m,n]>0 and study_region_mask[m,n] == 1:
                        valid_label.append(labeled_data[t,m,n,a])
                        valid_predicted.append(predicted[t,m,n,a])
                        
    print("R squared is: "+str(sklearn.metrics.r2_score(valid_label,valid_predicted)))
    print("RMSE is: "+str(mean_squared_error(valid_label,valid_predicted, squared=False)))

# %%
predicted = predicted[:,-1,:,:,:]
test_data_label=test_data_label[:,-1,:,:,:]
print(test_data_label.shape)
evaluate_method_performance(test_data_label, predicted,initial_ndvi.shape[0])
# Out:
# (178, 172, 63, 23)
# R squared is: 0.4992168947037148
# RMSE is: 0.09195312853485646

# %%
# find the valid test pixels for RMSE calculation

valid_testlabel = []
valid_predicted = []

for m in range(0,172):
    for n in range(0,63):
        for i in range(training_size+1,series.shape[0]):
            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:
                valid_testlabel.append(test_data_label[i-training_size-1,:,m,n])
                valid_predicted.append(predicted[i-training_size-1,:,m,n])

print(np.shape(valid_testlabel))
print(np.shape(valid_predicted))
# Out:
# (421620, 15, 23)
# (421620, 15, 23)

# %%
valid_testlabel = np.asarray(valid_testlabel)
valid_predicted = np.asarray(valid_predicted)

# %%
# Performance of the ConvLSTM model
from sklearn.metrics import mean_squared_error
#rmse =  mean_squared_error(valid_testlabel.flatten(), valid_predicted.flatten(), squared=False)
rmse =  mean_squared_error(valid_testlabel.ravel(), valid_predicted.ravel(), squared=False)
rmse
# Out:
# 0.08896369944234815

# %%
import sklearn
from sklearn import metrics
r2 = sklearn.metrics.r2_score(valid_testlabel.ravel(),valid_predicted.ravel())
print(r2)
# Out:
# 0.5254018026247154

# %%
n_steps = 15
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$", legend=True):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bo", label="Target")
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "rx", markersize=10, label="Prediction")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])
    if legend and (y or y_pred):
        plt.legend(fontsize=14, loc="upper left")

# %%
# draw a pic to show the prediction
ahead = step_ahead
plot_series(test_data_input[75,:,105, 30, 0])
plt.plot(np.arange(n_steps, n_steps + ahead), test_data_label[75,-1,105, 30,:], "bo-", label="Actual")
plt.plot(np.arange(n_steps, n_steps + ahead), predicted[75,-1,105, 30,:], "rx-", label="Forecast", markersize=10)
plt.axis([0, n_steps + ahead, -1, 1])
plt.legend(fontsize=14)

# %%
fig, axes = plt.subplots(3,4, figsize=(22,14))
fig.tight_layout(pad=4.0)
for i in range(12):
    plt.subplot(3,4,i+1)
    random_height = random.randint(0,172-1)
    random_width = random.randint(0,63-1)
    step = random.randint(0,test_data_input.shape[0]-1)

    while study_region_mask[random_height,random_width] == -1:
        random_height = random.randint(0,171)
        random_width = random.randint(0,63)
        step = random.randint(0,test_data_input.shape[0]-1)

    #step = 75
    #print(random_height)
    #print(random_width)
    #print(step)
    # draw a pic to show the prediction
    ahead = step_ahead
    plot_series(test_data_input[step,:,random_height, random_width, 0])
    #plt.subplot(2,3,i+1)
    plt.plot(np.arange(n_steps, n_steps + ahead), test_data_label[step,-1,random_height, random_width,:], "bo-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), predicted[step,-1,random_height, random_width,:], "rx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)
    plt.grid("on")
    plt.title("row: " + str(random_height) + "column: " + str(random_width))

# %%
"""
# find valid input data for baseline1
valid_testlabel1 = []
valid_baseline1 = []


for m in range(0,172):
    for n in range(0,63):
        for i in range(561,748-step_ahead):
            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:
                valid_testlabel1.append(test_data_label[i-561,m,n,:])
                valid_baseline1.append(test_data_input[i-561,-1,m,n,:])
"""
# Out:
# '\n# find valid input data for baseline1\nvalid_testlabel1 = []\nvalid_baseline1 = []\n\n\nfor m in range(0,172):\n    for n in range(0,63):\n        for i in range(561,748-step_ahead):\n            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:\n                valid_testlabel1.append(test_data_label[i-561,m,n,:])\n                valid_baseline1.append(test_data_input[i-561,-1,m,n,:])\n'

# %%
#print(np.shape(valid_baseline1))

#print(np.shape(valid_testlabel1))

# %%
"""
#baseline #1: simply guess as the same of last step
pred_baseline1 = test_data_input[::, -1, ::, ::, 0]
pred_baseline1.shape
"""
# Out:
# '\n#baseline #1: simply guess as the same of last step\npred_baseline1 = test_data_input[::, -1, ::, ::, 0]\npred_baseline1.shape\n'

# %%
"""
# performance of the baseline#1
rmse =  mean_squared_error(test_data_label.flatten(), pred_baseline1.flatten(), squared=False)
rmse
"""
# Out:
# '\n# performance of the baseline#1\nrmse =  mean_squared_error(test_data_label.flatten(), pred_baseline1.flatten(), squared=False)\nrmse\n'

# %%
# performance of the baseline#1
#rmse =  mean_squared_error(valid_testlabel1, valid_baseline1, squared=False)
#rmse

# %%
#r2 = sklearn.metrics.r2_score(valid_testlabel1,valid_baseline1)
#print(r2)

# %%
"""
# find valid input data for baseline2
valid_testlabel2 = []
valid_baseline2 = []

for m in range(0,172):
    for n in range(0,63):
        for i in range(561,748-step_ahead):
            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:
                valid_testlabel2.append(test_data_label[i-561,m,n,:])
                pred_baseline2 = test_data_input[i-561, ::, m, n, :]
                valid_baseline2.append(np.mean(pred_baseline2,axis = 0))


print(np.shape(valid_testlabel2))
print(np.shape(valid_baseline2))
"""
# Out:
# '\n# find valid input data for baseline2\nvalid_testlabel2 = []\nvalid_baseline2 = []\n\nfor m in range(0,172):\n    for n in range(0,63):\n        for i in range(561,748-step_ahead):\n            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:\n                valid_testlabel2.append(test_data_label[i-561,m,n,:])\n                pred_baseline2 = test_data_input[i-561, ::, m, n, :]\n                valid_baseline2.append(np.mean(pred_baseline2,axis = 0))\n\n\nprint(np.shape(valid_testlabel2))\nprint(np.shape(valid_baseline2))\n'

# %%
"""
# baseline #2: average of the past 15 steps
pred_baseline2 = test_data_input[::, ::, ::, ::, 0]
pred_baseline2 = np.mean(pred_baseline2, axis=1)
pred_baseline2.shape
"""
# Out:
# '\n# baseline #2: average of the past 15 steps\npred_baseline2 = test_data_input[::, ::, ::, ::, 0]\npred_baseline2 = np.mean(pred_baseline2, axis=1)\npred_baseline2.shape\n'

# %%
# performance of the baseline#2
#rmse =  mean_squared_error(valid_testlabel2, valid_baseline2, squared=False)
#rmse

# %%
#r2 = sklearn.metrics.r2_score(valid_testlabel2,valid_baseline2)
#print(r2)

# %%
#pred_baseline1 = test_data_input[::, -1, ::, ::, 0]
#pred_baseline2 = test_data_input[::, ::, ::, ::, 0]

# %%
"""
time_steps = range(training_size+1, training_size+1+len(test_data_label))

fig, axes = plt.subplots(3,4, figsize=(22,14))
fig.tight_layout(pad=4.0)
for i in range(1,13):
    plt.subplot(3,4,i)
    #for j in range(1,3):
    predict_series = predicted[j]

    plt.imshow(predict_series)
        #plt.ylim(0.0,1.0)
    plt.title("time = " + str(561+i))
"""
# Out:
# '\ntime_steps = range(training_size+1, training_size+1+len(test_data_label))\n\nfig, axes = plt.subplots(3,4, figsize=(22,14))\nfig.tight_layout(pad=4.0)\nfor i in range(1,13):\n    plt.subplot(3,4,i)\n    #for j in range(1,3):\n    predict_series = predicted[j]\n\n    plt.imshow(predict_series)\n        #plt.ylim(0.0,1.0)\n    plt.title("time = " + str(561+i))\n'

# %%
"""
# Visualize the predictions of 12 pixels
time_steps = range(training_size+1, training_size+1+len(test_data_label))

fig, axes = plt.subplots(3,4, figsize=(22,14))
fig.tight_layout(pad=4.0)
for i in range(1,13):
    #for j in range(1,3):

    plt.subplot(3,4,i)

    pixel_y = random.randint(0,ndvi.height-1)
    pixel_x = random.randint(0,ndvi.width-1)

    while study_region_mask[pixel_y,pixel_x] == -1:
        pixel_y = random.randint(0,ndvi.height-1)
        pixel_x = random.randint(0,ndvi.width-1)

    true_series = test_data_label[:,pixel_y,pixel_x]
    predict_series = predicted[:,pixel_y,pixel_x]
    plt.plot(time_steps, true_series,"b-", label='True')
    plt.plot(time_steps, predict_series,"r--", label='Predicted')
    #plt.ylim(0.0,1.0)
    plt.xlabel("Time Steps")
    plt.ylabel("NDVI")
    plt.legend()
    plt.grid('on')
    plt.title('Pixel at row:'+str(pixel_y)+" column:"+str(pixel_x))
"""
# Out:
# '\n# Visualize the predictions of 12 pixels\ntime_steps = range(training_size+1, training_size+1+len(test_data_label))\n\nfig, axes = plt.subplots(3,4, figsize=(22,14))\nfig.tight_layout(pad=4.0)\nfor i in range(1,13):\n    #for j in range(1,3):\n\n    plt.subplot(3,4,i)\n\n    pixel_y = random.randint(0,ndvi.height-1)\n    pixel_x = random.randint(0,ndvi.width-1)\n\n    while study_region_mask[pixel_y,pixel_x] == -1:\n        pixel_y = random.randint(0,ndvi.height-1)\n        pixel_x = random.randint(0,ndvi.width-1)\n\n    true_series = test_data_label[:,pixel_y,pixel_x]\n    predict_series = predicted[:,pixel_y,pixel_x]\n    plt.plot(time_steps, true_series,"b-", label=\'True\')\n    plt.plot(time_steps, predict_series,"r--", label=\'Predicted\')\n    #plt.ylim(0.0,1.0)\n    plt.xlabel("Time Steps")\n    plt.ylabel("NDVI")\n    plt.legend()\n    plt.grid(\'on\')\n    plt.title(\'Pixel at row:\'+str(pixel_y)+" column:"+str(pixel_x))\n'

# %%
"""
# calculate temporal rmse of 12 randomly picked pixels
x = []
y = []
for j in range(1,13):
    pixel_y = random.randint(0,ndvi.height-1)
    pixel_x = random.randint(0,ndvi.width-1)

    while study_region_mask[pixel_y,pixel_x] == -1:
        pixel_y = random.randint(0,ndvi.height-1)
        pixel_x = random.randint(0,ndvi.width-1)

    x.append(pixel_x)
    y.append(pixel_y)

    tem_label = []
    tem_pred = []
    for i in range(561,748):
        if qa_arr[i,pixel_y,pixel_x] == 0 and ndvi_arr[i,pixel_y,pixel_x] > 0:
            tem_label.append(test_data_label[i-561,pixel_y,pixel_x])
            tem_pred.append(predicted[i-561,pixel_y,pixel_x])

    tem_rmse =  mean_squared_error(tem_label, tem_pred, squared=False)
    print("the temporal RMSE of pixel (" + str(pixel_y) + "," + str(pixel_x) +") " + "is " + str(tem_rmse))
"""
# Out:
# '\n# calculate temporal rmse of 12 randomly picked pixels\nx = []\ny = []\nfor j in range(1,13):\n    pixel_y = random.randint(0,ndvi.height-1)\n    pixel_x = random.randint(0,ndvi.width-1)\n\n    while study_region_mask[pixel_y,pixel_x] == -1:\n        pixel_y = random.randint(0,ndvi.height-1)\n        pixel_x = random.randint(0,ndvi.width-1)\n\n    x.append(pixel_x)\n    y.append(pixel_y)\n\n    tem_label = []\n    tem_pred = []\n    for i in range(561,748):\n        if qa_arr[i,pixel_y,pixel_x] == 0 and ndvi_arr[i,pixel_y,pixel_x] > 0:\n            tem_label.append(test_data_label[i-561,pixel_y,pixel_x])\n            tem_pred.append(predicted[i-561,pixel_y,pixel_x])\n\n    tem_rmse =  mean_squared_error(tem_label, tem_pred, squared=False)\n    print("the temporal RMSE of pixel (" + str(pixel_y) + "," + str(pixel_x) +") " + "is " + str(tem_rmse))\n'

# %%
"""
# calculate temporal r2 of 12 randomly picked pixels
for j in range(1,13):


    tem_label = []
    tem_pred = []
    for i in range(561,748):
        if qa_arr[i,y[j-1],x[j-1]] == 0 and ndvi_arr[i,y[j-1],x[j-1]] > 0:
            tem_label.append(test_data_label[i-561,y[j-1],x[j-1]])
            tem_pred.append(predicted[i-561,y[j-1],x[j-1]])
    tem_r2 = sklearn.metrics.r2_score(tem_label,tem_pred)
    
    print("the temporal R2 of pixel (" + str(y[j-1]) + "," + str(x[j-1]) +") " + "is " + str(tem_r2))
"""
# Out:
# '\n# calculate temporal r2 of 12 randomly picked pixels\nfor j in range(1,13):\n\n\n    tem_label = []\n    tem_pred = []\n    for i in range(561,748):\n        if qa_arr[i,y[j-1],x[j-1]] == 0 and ndvi_arr[i,y[j-1],x[j-1]] > 0:\n            tem_label.append(test_data_label[i-561,y[j-1],x[j-1]])\n            tem_pred.append(predicted[i-561,y[j-1],x[j-1]])\n    tem_r2 = sklearn.metrics.r2_score(tem_label,tem_pred)\n    \n    print("the temporal R2 of pixel (" + str(y[j-1]) + "," + str(x[j-1]) +") " + "is " + str(tem_r2))\n'

# %%
"""
# calculate per pixel rmse
spatial_rmse = np.random.rand(ndvi.height,ndvi.width)

for i in range(ndvi.height):
    for j in range(ndvi.width):
        this_true = test_data_label[:,i,j]
        this_predict = predicted[:,i,j]
        this_rmse = mean_squared_error(this_true,this_predict, squared=False)
        spatial_rmse[i,j] = this_rmse
"""
# Out:
# '\n# calculate per pixel rmse\nspatial_rmse = np.random.rand(ndvi.height,ndvi.width)\n\nfor i in range(ndvi.height):\n    for j in range(ndvi.width):\n        this_true = test_data_label[:,i,j]\n        this_predict = predicted[:,i,j]\n        this_rmse = mean_squared_error(this_true,this_predict, squared=False)\n        spatial_rmse[i,j] = this_rmse\n'

# %%
"""
plt.figure(figsize=(5,10))
plt.imshow(spatial_rmse, cmap="Greys_r")
plt.colorbar()
"""
# Out:
# '\nplt.figure(figsize=(5,10))\nplt.imshow(spatial_rmse, cmap="Greys_r")\nplt.colorbar()\n'
