# %%
import rasterio as ro
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import random
import math
import pandas
from scipy import optimize

#from keras_tuner.engine.hyperparameters import HyperParameters

from scipy.signal import savgol_filter

# %%
# load the data
ndvi = ro.open("Data/NDVI.grd")

covariates = ro.open("Data/covariates_250m_peninsula.grd")

p1 = ro.open("Data/newprec_01.tif")

p7 = ro.open("Data/newprec_07.tif")

fire_history = ro.open("Data/age.grd")

qa_data = ro.open("Data/QA.grd")

# %%
# read the shape of covariates
covariates_arr = covariates.read()

np.shape(covariates_arr)
# Out:
# (12, 172, 63)

# %%
# read the shape of NDVI
ndvi_arr = ndvi.read()

np.shape(ndvi_arr)
# Out:
# (748, 172, 63)

# %%
# read the shape of QA
qa_arr = qa_data.read()

np.shape(qa_arr)
# Out:
# (748, 172, 63)

# %%
# read the shape of fire history
fire_arr = fire_history.read()

np.shape(fire_arr)
# Out:
# (748, 172, 63)

# %%
# read the precipitation data
p1_arr = p1.read()
p1_arr.shape
p7_arr = p7.read()
p7_arr.shape

p1_arr = p1_arr[:,:172,:63]

p7_arr = p7_arr[:,:172,:63]

# %%
p1_arr.shape
# Out:
# (1, 172, 63)

# %%
# replace the negative value with nan data in precipitation
for m in range(0,172):
  for n in range(0,63):
    if p1_arr[:,m,n] < 0 :
      p1_arr[:,m,n] = np.nan
    else:
      pass


for m in range(0,172):
  for n in range(0,63):
    if p7_arr[:,m,n] < 0 :
      p7_arr[:,m,n] = np.nan
    else:
      pass

# %%
# replace the precipitation value
covariates_arr[9] = p1_arr
covariates_arr[10] = p7_arr

# %%
# read the shape of new covariates 
np.shape(covariates_arr)
# Out:
# (12, 172, 63)

# %%
# create a mask based on the environmental variables and fire history
study_region_mask = np.zeros((ndvi.height,ndvi.width))


for i in range(study_region_mask.shape[0]):
    for j in range(study_region_mask.shape[1]):
        found_nan = False
        for var_index in range(covariates_arr.shape[0]):
            if np.isnan(covariates_arr[var_index,i,j]):
                found_nan =True
                break

        for time_step in range(fire_arr.shape[0]):
            if np.isnan(fire_arr[time_step,i,j]):
                found_nan =True
                break
        
        if found_nan:
            study_region_mask[i,j] = -1
        else:
            study_region_mask[i,j] = 1

plt.imshow(study_region_mask)

# %%
nan_value = 0

# %%
# a mask out function
def mask_layer(input_layer, mask_layer):
    for i in range(mask_layer.shape[0]):
        for j in range(mask_layer.shape[1]):
            if mask_layer[i,j]==-1:
                input_layer[i,j] = nan_value # replace the nan value in the input data

    return input_layer

# %%
#savgol_filter to smooth the data
#ndvi_times = range(1,ndvi.count+1)

qa_value_array = qa_data.read()

ndvi_smoothed = []

for m in range(0,ndvi.height):
  for n in range(0,ndvi.width):

    ndvi_ori = ndvi_arr[:,m,n]
    
    if study_region_mask[m,n] ==-1:
      ndvi_smoothed.append(ndvi_ori)
      continue
    
    
    qa_value = qa_arr[:,m,n]
    # for i in ndvi_times:
    #   ndvi_data = ndvi.read(i)
    #   ndvi_pixel = ndvi_data[m,n]
    #   ndvi_ori.append(ndvi_pixel) #将每个像素上所有时间点上的值存入数组


    #   qa = qa_data.read(i)
    #   qa_pixel = qa[m,n]
    #   qa_value.append(qa_pixel) #将每个像素上所有时间点上的QA值存入数组

    smoothed = savgol_filter(ndvi_ori,7,2)

    for t in range(qa_value.shape[0]):
      if qa_value[t] == 0 and ndvi_ori[t]>0:
        smoothed[t] = ndvi_ori[t]
      # else:
      #   pass

    ndvi_smoothed.append(smoothed)


ndvi_smoothed = np.asarray(ndvi_smoothed)

# %%
np.shape(ndvi_smoothed)
# Out:
# (10836, 748)

# %%
# created the dataset contains ONLY SMOOTHED NDVI DATA
smoothed_dataset = np.zeros((ndvi.count,ndvi.height,ndvi.width,1))
for time_steps in range(0,ndvi.count):
  for m in range(0,ndvi.height):
    for n in range(0,ndvi.width):
      smoothed_dataset[time_steps,m,n,0] = ndvi_smoothed[63*m+n][time_steps]

print(np.shape(smoothed_dataset))
# Out:
# (748, 172, 63, 1)

# %%
# visualize random 12 NDVI values of SMOOTHED NDVI DATASET
plt.figure(figsize=(15,12))
for i in range(1,13):
    plt.subplot(4,4,i)
    random_time = random.randint(0,ndvi.count-1)
    plt.imshow(smoothed_dataset[random_time,:,:,0])
    plt.axis('off')

# %%
# filter the SMOOTHED DATA with the mask

for time_steps in range(0,smoothed_dataset.shape[0]):
    smoothed_dataset[time_steps,:,:,:] = mask_layer(smoothed_dataset[time_steps,:,:,:],study_region_mask)


print(np.shape(smoothed_dataset))
# Out:
# (748, 172, 63, 1)

# %%
# visualize random 12 NDVI values of SMOOTHED and masked NDVI DATASET
plt.figure(figsize=(15,12))
for i in range(1,13):
    plt.subplot(4,4,i)
    random_time = random.randint(0,ndvi.count-1)
    plt.imshow(smoothed_dataset[random_time,:,:,0])
    plt.axis('off')

# %% [markdown]
# convLSTM part

# %%
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
#!!pip install tensorflow

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
step_ahead = 23

# %%
tf.random.set_seed(42)

# %%
def create_model():
    tf.random.set_seed(42)
    np.random.seed(42)

    model = keras.Sequential(
        [
            layers.LSTM(541,return_sequences = True,input_shape=[None, 172*63]),
            layers.LSTM(541,return_sequences = True),
            #layers.SimpleRNN(541,return_sequences = True),
            #layers.SimpleRNN(541,return_sequences = True),
            #layers.SimpleRNN(541),

            layers.TimeDistributed(keras.layers.Dense(172*63*step_ahead))
            #layers.Dense(172*63)#, activation="linear")
        ]
    )
    model.compile(loss=keras.losses.mean_squared_error, optimizer=keras.optimizers.Adam(learning_rate=0.0001))
    return model

# %%
series = []
for i in range(0,ndvi.count-15-step_ahead+1):
    this_series_arr = []
    for j in range(0,15+step_ahead):
        this_series = smoothed_dataset[i+j,:,:,:]
        this_series_arr.append(this_series)

    series.append(this_series_arr)

series = np.asarray(series)

print(series.shape)

Y = np.empty((series.shape[0],15,172,63,step_ahead))

for k in range(1, step_ahead + 1):
    Y[:,:,:,:, k - 1] = series[:, k:k + 15,:,:, 0]

X = series[:,:15,:,:,:]

training_size = int(0.75*series.shape[0]) # 561

initial_ndvi = X[:training_size,...]
next_ndvi = Y[:training_size,...]

test_data_input = X[training_size:,...]
test_data_label = Y[training_size:,...]
# Out:
# (711, 38, 172, 63, 1)

# %%
initial_ndvi.shape, next_ndvi.shape
# Out:
# ((533, 15, 172, 63, 1), (533, 15, 172, 63, 23))

# %%
initial_ndvi = initial_ndvi.reshape((next_ndvi.shape[0],15,172*63))

# %%
next_ndvi = next_ndvi.reshape((initial_ndvi.shape[0],15,172*63*step_ahead))

# %%
initial_ndvi.shape, next_ndvi.shape
# Out:
# ((533, 15, 10836), (533, 15, 249228))

# %%
def x_generator():
    for i in range(initial_ndvi.shape[0]):
        yield initial_ndvi[i]

# %%
def y_generator():
    for i in range(next_ndvi.shape[0]):
        yield next_ndvi[i]

# %%
x_dataset = tf.data.Dataset.from_generator(x_generator,output_types=tf.float32)

# %%
y_dataset = tf.data.Dataset.from_generator(y_generator,output_types=tf.float32)

# %%
combine_dataset = tf.data.Dataset.zip((x_dataset, y_dataset))

# %%
combine_batches = combine_dataset.batch(100)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor="loss",patience=3)
#Train the model
LSTM_model = create_model()



epochs = 70


for x,y in combine_batches.take(6):
    print(np.shape([x_arr.numpy() for x_arr in x]))
    print(np.shape([y_arr.numpy() for y_arr in y]))
    history = LSTM_model.fit(
        np.asarray([x_arr.numpy() for x_arr in x]),
        np.asarray([y_arr.numpy() for y_arr in y]),
        batch_size=1,
        epochs=epochs,
        verbose=1,
        validation_split=0.1,
        callbacks=[callback]
    )


    loss_train = history.history["loss"]
    loss_val = history.history['val_loss']

    plt.plot(loss_train, 'g', label='loss')
    plt.plot(loss_val, 'b', label='validation loss')
    plt.title('Training and Validation loss')
    plt.ylim(0,0.03)
    plt.legend()
    plt.show()

LSTM_model.save('PretrainedModel/LSTM_smoothed_NDVI_only_linear_activation_flatten_23steps.h5')
# Out:
# (100, 15, 10836)
# (100, 15, 249228)
# Epoch 1/70
# 90/90 [==============================] - 49s 112ms/step - loss: 0.0250 - val_loss: 0.0044
# Epoch 2/70
# 90/90 [==============================] - 9s 102ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 3/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 4/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 5/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 6/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 7/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 8/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 9/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 10/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 11/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 12/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 13/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 14/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 15/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 16/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 17/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 18/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 19/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 20/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 21/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 22/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 23/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 24/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 25/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 26/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 27/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 28/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 29/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 30/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 31/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 32/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 33/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 34/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 35/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 36/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 37/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 38/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 39/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 40/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 41/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 42/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 43/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 44/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 45/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 46/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 47/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 48/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 49/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 50/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 51/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 52/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 53/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 54/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 55/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 56/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 57/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 58/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 59/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 60/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 61/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 62/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 63/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 64/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 65/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 66/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 67/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 68/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 69/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 70/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0021
# (100, 15, 10836)
# (100, 15, 249228)
# Epoch 1/70
# 90/90 [==============================] - 10s 106ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 2/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 3/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 4/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 5/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 6/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 7/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 8/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 9/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 10/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 11/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 12/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 13/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 14/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 15/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 16/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 17/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 18/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 19/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 20/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 21/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 22/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 23/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 24/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 25/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 26/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 27/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 28/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 29/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 30/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 31/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 32/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 33/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 34/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 35/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 36/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 37/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 38/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 39/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 40/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 41/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 42/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 43/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 44/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 45/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 46/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 47/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 48/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 49/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 50/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 51/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 52/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 53/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 54/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 55/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 56/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 57/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 58/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 59/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 60/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 61/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 62/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 63/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 64/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 65/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 66/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0011 - val_loss: 0.0019
# (100, 15, 10836)
# (100, 15, 249228)
# Epoch 1/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 2/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 3/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 4/70
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 5/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 6/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 7/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 8/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 9/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 10/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 11/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 12/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 13/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 14/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 15/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 16/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 17/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 18/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 19/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 20/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 21/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 22/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 23/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 24/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 25/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 26/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 27/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 28/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0025
# (100, 15, 10836)
# (100, 15, 249228)
# Epoch 1/70
# 90/90 [==============================] - ETA: 0s - loss: 0.0021Epoch 2/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 3/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 4/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 5/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 6/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 7/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 8/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 9/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 10/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 11/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 12/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 13/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 14/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 15/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 16/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 17/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 18/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 19/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 20/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 21/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 22/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 23/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 24/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 25/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 26/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 27/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 28/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 29/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 30/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 31/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 32/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 33/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 34/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 35/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 36/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 37/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 38/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 39/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 40/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 41/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 42/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 43/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.9274e-04 - val_loss: 0.0018
# Epoch 44/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.6464e-04 - val_loss: 0.0018
# Epoch 45/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.6149e-04 - val_loss: 0.0017
# Epoch 46/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 47/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.5407e-04 - val_loss: 0.0017
# Epoch 48/70
# 90/90 [==============================] - 9s 105ms/step - loss: 9.3223e-04 - val_loss: 0.0017
# Epoch 49/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.2080e-04 - val_loss: 0.0017
# Epoch 50/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.3065e-04 - val_loss: 0.0017
# Epoch 51/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.2767e-04 - val_loss: 0.0018
# Epoch 52/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.0234e-04 - val_loss: 0.0018
# Epoch 53/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.1437e-04 - val_loss: 0.0017
# Epoch 54/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.0474e-04 - val_loss: 0.0017
# Epoch 55/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.0363e-04 - val_loss: 0.0018
# (100, 15, 10836)
# (100, 15, 249228)
# Epoch 1/70
# 90/90 [==============================] - 10s 106ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 2/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 3/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 4/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 5/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 6/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 7/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 8/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 9/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 10/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 11/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 12/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 13/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 14/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 15/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 16/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 17/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 18/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 19/70
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 20/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 21/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 22/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 23/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 24/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 25/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 26/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 27/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 28/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 29/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 30/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 31/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 32/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 33/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 34/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 35/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 36/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 37/70
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 38/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.9347e-04 - val_loss: 0.0018
# Epoch 39/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.8342e-04 - val_loss: 0.0017
# Epoch 40/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.9202e-04 - val_loss: 0.0018
# Epoch 41/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.6925e-04 - val_loss: 0.0018
# Epoch 42/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.7709e-04 - val_loss: 0.0017
# Epoch 43/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.4425e-04 - val_loss: 0.0018
# Epoch 44/70
# 90/90 [==============================] - 9s 105ms/step - loss: 9.3612e-04 - val_loss: 0.0018
# Epoch 45/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.2784e-04 - val_loss: 0.0017
# Epoch 46/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.1039e-04 - val_loss: 0.0018
# Epoch 48/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.9311e-04 - val_loss: 0.0017
# Epoch 49/70
# 90/90 [==============================] - 9s 105ms/step - loss: 8.8034e-04 - val_loss: 0.0018
# Epoch 50/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.8033e-04 - val_loss: 0.0017
# Epoch 51/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.8118e-04 - val_loss: 0.0018
# Epoch 52/70
# 90/90 [==============================] - 9s 104ms/step - loss: 9.1741e-04 - val_loss: 0.0017
# Epoch 53/70
# 90/90 [==============================] - 9s 105ms/step - loss: 8.4500e-04 - val_loss: 0.0017
# Epoch 54/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.8318e-04 - val_loss: 0.0018
# Epoch 55/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.2377e-04 - val_loss: 0.0017
# Epoch 56/70
# 90/90 [==============================] - 9s 105ms/step - loss: 8.0941e-04 - val_loss: 0.0017
# Epoch 57/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.0272e-04 - val_loss: 0.0017
# Epoch 58/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.0340e-04 - val_loss: 0.0018
# Epoch 59/70
# 90/90 [==============================] - 9s 104ms/step - loss: 7.8409e-04 - val_loss: 0.0017
# Epoch 60/70
# 90/90 [==============================] - 9s 104ms/step - loss: 7.8924e-04 - val_loss: 0.0017
# Epoch 61/70
# 90/90 [==============================] - 9s 104ms/step - loss: 7.8995e-04 - val_loss: 0.0018
# Epoch 62/70
# 90/90 [==============================] - 9s 104ms/step - loss: 8.8424e-04 - val_loss: 0.0018
# (33, 15, 10836)
# (33, 15, 249228)
# Epoch 1/70
# 29/29 [==============================] - 3s 108ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 2/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 3/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 4/70
# 29/29 [==============================] - 3s 105ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 5/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 6/70
# 29/29 [==============================] - 3s 107ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 7/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 8/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 9/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 10/70
# 29/29 [==============================] - 3s 106ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 11/70
# 29/29 [==============================] - 3s 106ms/step - loss: 9.9857e-04 - val_loss: 0.0013
# Epoch 12/70
# 29/29 [==============================] - 3s 106ms/step - loss: 9.9226e-04 - val_loss: 0.0013
# Epoch 13/70
# 29/29 [==============================] - 3s 105ms/step - loss: 9.7889e-04 - val_loss: 0.0014
# Epoch 14/70
# 29/29 [==============================] - 3s 105ms/step - loss: 9.6100e-04 - val_loss: 0.0013
# Epoch 15/70
# 29/29 [==============================] - 3s 105ms/step - loss: 9.2965e-04 - val_loss: 0.0013
# Epoch 16/70
# 29/29 [==============================] - 3s 106ms/step - loss: 9.1142e-04 - val_loss: 0.0013
# Epoch 17/70
# 29/29 [==============================] - 3s 106ms/step - loss: 8.9791e-04 - val_loss: 0.0013
# Epoch 18/70
# 29/29 [==============================] - 3s 106ms/step - loss: 8.9079e-04 - val_loss: 0.0012
# Epoch 19/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.7873e-04 - val_loss: 0.0013
# Epoch 20/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.6471e-04 - val_loss: 0.0013
# Epoch 21/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.4617e-04 - val_loss: 0.0013
# Epoch 22/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.4515e-04 - val_loss: 0.0013
# Epoch 23/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.7028e-04 - val_loss: 0.0014
# Epoch 24/70
# 29/29 [==============================] - 3s 106ms/step - loss: 8.4233e-04 - val_loss: 0.0012
# Epoch 25/70
# 29/29 [==============================] - 3s 105ms/step - loss: 8.0080e-04 - val_loss: 0.0012
# Epoch 26/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.9316e-04 - val_loss: 0.0012
# Epoch 27/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.9453e-04 - val_loss: 0.0012
# Epoch 28/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.8803e-04 - val_loss: 0.0012
# Epoch 29/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.5875e-04 - val_loss: 0.0012
# Epoch 30/70
# 29/29 [==============================] - 3s 107ms/step - loss: 7.4483e-04 - val_loss: 0.0012
# Epoch 31/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.3242e-04 - val_loss: 0.0012
# Epoch 32/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.2384e-04 - val_loss: 0.0012
# Epoch 33/70
# 29/29 [==============================] - 3s 106ms/step - loss: 7.0948e-04 - val_loss: 0.0012
# Epoch 34/70
# 29/29 [==============================] - 3s 106ms/step - loss: 7.0644e-04 - val_loss: 0.0012
# Epoch 35/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.0341e-04 - val_loss: 0.0012
# Epoch 36/70
# 29/29 [==============================] - 3s 105ms/step - loss: 7.0841e-04 - val_loss: 0.0012
# Epoch 37/70
# 29/29 [==============================] - 3s 105ms/step - loss: 6.8650e-04 - val_loss: 0.0012
# Epoch 38/70
# 29/29 [==============================] - 3s 105ms/step - loss: 6.6855e-04 - val_loss: 0.0012
# Epoch 39/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.5171e-04 - val_loss: 0.0012
# Epoch 40/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.4959e-04 - val_loss: 0.0012
# Epoch 41/70
# 29/29 [==============================] - 3s 107ms/step - loss: 6.3234e-04 - val_loss: 0.0012
# Epoch 42/70
# 29/29 [==============================] - 3s 105ms/step - loss: 6.1920e-04 - val_loss: 0.0011
# Epoch 43/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.1307e-04 - val_loss: 0.0011
# Epoch 44/70
# 29/29 [==============================] - 3s 105ms/step - loss: 6.1800e-04 - val_loss: 0.0012
# Epoch 45/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.1101e-04 - val_loss: 0.0011
# Epoch 46/70
# 29/29 [==============================] - 3s 105ms/step - loss: 6.1458e-04 - val_loss: 0.0012
# Epoch 47/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.1815e-04 - val_loss: 0.0011
# Epoch 48/70
# 29/29 [==============================] - 3s 107ms/step - loss: 5.8032e-04 - val_loss: 0.0011
# Epoch 49/70
# 29/29 [==============================] - 3s 106ms/step - loss: 5.6173e-04 - val_loss: 0.0011
# Epoch 50/70
# 29/29 [==============================] - 3s 106ms/step - loss: 5.5235e-04 - val_loss: 0.0011
# Epoch 51/70
# 29/29 [==============================] - 3s 106ms/step - loss: 5.7448e-04 - val_loss: 0.0011
# Epoch 52/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.4714e-04 - val_loss: 0.0011
# Epoch 53/70
# 29/29 [==============================] - 3s 106ms/step - loss: 5.3209e-04 - val_loss: 0.0011
# Epoch 54/70
# 29/29 [==============================] - 3s 106ms/step - loss: 5.2335e-04 - val_loss: 0.0011
# Epoch 55/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.2542e-04 - val_loss: 0.0011
# Epoch 56/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.1727e-04 - val_loss: 0.0011
# Epoch 57/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.2252e-04 - val_loss: 0.0012
# Epoch 58/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.0573e-04 - val_loss: 0.0011
# Epoch 59/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.0325e-04 - val_loss: 0.0012
# Epoch 60/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.2149e-04 - val_loss: 0.0012
# Epoch 61/70
# 29/29 [==============================] - 3s 106ms/step - loss: 6.2555e-04 - val_loss: 0.0013
# Epoch 62/70
# 29/29 [==============================] - 3s 105ms/step - loss: 5.2199e-04 - val_loss: 0.0011

# %%
loss_train = history.history["loss"]
loss_val = history.history['val_loss']

plt.plot(loss_train, 'g', label='loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')

plt.legend()
plt.show()

# %%
LSTM_model = tf.keras.models.load_model('PretrainedModel/LSTM_smoothed_NDVI_only_linear_activation_flatten_23steps.h5')
LSTM_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 541)         24621992
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 541)         2343612
# _________________________________________________________________
# time_distributed (TimeDistri (None, None, 249228)      135081576
# =================================================================
# Total params: 162,047,180
# Trainable params: 162,047,180
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
# create test dataset using the remaining 25% data 
test_data_input = []
test_data_label = []

for sample_i in range(training_size, ndvi.count):
    
    test_data_label.append(smoothed_dataset[sample_i,:,:,0])
    this_initial_sequence = []
    for t in range(sample_i-15,sample_i): # each sample has 15 time steps
        this_initial = smoothed_dataset[t,:,:,0]
        #this_initial = this_initial[..., np.newaxis]
        this_initial_sequence.append(this_initial)
        
    test_data_input.append(this_initial_sequence)
    
    
test_data_input = np.asarray(test_data_input)
test_data_label = np.asarray(test_data_label)
"""
# Out:
# '\n# create test dataset using the remaining 25% data \ntest_data_input = []\ntest_data_label = []\n\nfor sample_i in range(training_size, ndvi.count):\n    \n    test_data_label.append(smoothed_dataset[sample_i,:,:,0])\n    this_initial_sequence = []\n    for t in range(sample_i-15,sample_i): # each sample has 15 time steps\n        this_initial = smoothed_dataset[t,:,:,0]\n        #this_initial = this_initial[..., np.newaxis]\n        this_initial_sequence.append(this_initial)\n        \n    test_data_input.append(this_initial_sequence)\n    \n    \ntest_data_input = np.asarray(test_data_input)\ntest_data_label = np.asarray(test_data_label)\n'

# %%
print(test_data_input.shape)
print(test_data_label.shape)
# Out:
# (178, 15, 172, 63, 1)
# (178, 15, 172, 63, 23)

# %%
test_data_input = test_data_input.reshape((test_data_label.shape[0],15,172*63))
#test_data_label = test_data_label.reshape(187,172,63)
#test_data_label = test_data_label.reshape(187,172*63)

# %%
print(test_data_input.shape)
print(test_data_label.shape)
# Out:
# (178, 15, 10836)
# (178, 15, 172, 63, 23)

# %%
# visualize random 12 test label
plt.figure(figsize=(15,12))
for i in range(1,13):
    plt.subplot(3,4,i)
    random_time = random.randint(0,test_data_label.shape[0])
    plt.imshow(test_data_label[random_time,-1,:,:,-1])
    plt.axis('off')

# %%
def test_input_generator():
    for i in range(test_data_input.shape[0]):
        yield test_data_input[i]

def test_label_generator():
    for i in range(test_data_label.shape[0]):
        yield test_data_label[i]

# %%
test_input_dataset = tf.data.Dataset.from_generator(test_input_generator,output_types=tf.float32)
test_label_dataset = tf.data.Dataset.from_generator(test_label_generator,output_types=tf.float32)

# %%
test_input_batches = test_input_dataset.batch(30) #6 batches
test_label_batches = test_label_dataset.batch(30)

# %%
predicition_result = []

for test_input in test_input_batches.take(6):
    a = np.asarray([x_arr.numpy() for x_arr in test_input])
    predicted = LSTM_model.predict(a) 
    predicted_reshape = predicted.reshape((predicted.shape[0],15,172,63,step_ahead))
    predicition_result.append(predicted_reshape)

# %%
prediction = np.empty((test_data_input.shape[0],15,172,63,step_ahead))

for k in range(5):
    for i in range(30):
        current_prediction_result = predicition_result[k]
        prediction[k*30+i,:,:,:,:] = current_prediction_result[i,:,:,:,:]

sixth_prediction_result = predicition_result[5]
for i in range(int(test_data_input.shape[0]-150)):
    prediction[150+i,:,:,:,:] = sixth_prediction_result [i,:,:,:,:]

# %%
predicted = prediction

# %%
predicted = predicted[:,-1,:,:,:]

# %%
# Visualize some predicted NDVI
plt.figure(figsize=(15,12))
for i in range(1,13):
    plt.subplot(3,4,i)
    random_time = random.randint(0,test_data_label.shape[0])
    plt.imshow(predicted[random_time,:,:,-1])
    plt.axis('off')

# %%
# find the valid test pixels for RMSE calculation
"""
valid_testlabel = []
valid_predicted = []


for m in range(0,172):
    for n in range(0,63):
        for i in range(initial_ndvi.shape[0],series.shape[0]):

            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:
                valid_testlabel.append(test_data_label[i-initial_ndvi.shape[0],-1,m,n,:])
                valid_predicted.append(predicted[i-initial_ndvi.shape[0],m,n,:])

print(np.shape(valid_testlabel))
print(np.shape(valid_predicted))
"""
# Out:
# '\nvalid_testlabel = []\nvalid_predicted = []\n\n\nfor m in range(0,172):\n    for n in range(0,63):\n        for i in range(initial_ndvi.shape[0],series.shape[0]):\n\n            if qa_arr[i,m,n] == 0 and ndvi_arr[i,m,n]>0 and study_region_mask[m,n] == 1:\n                valid_testlabel.append(test_data_label[i-initial_ndvi.shape[0],-1,m,n,:])\n                valid_predicted.append(predicted[i-initial_ndvi.shape[0],m,n,:])\n\nprint(np.shape(valid_testlabel))\nprint(np.shape(valid_predicted))\n'

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
#from keras_tuner.engine.hyperparameters import HyperParameters
import sklearn
def evaluate_method_performance(labeled_data, predicted, n_training_time_steps):
    n_test_time_steps = labeled_data.shape[0]
    time_step_ahead = labeled_data.shape[3]
    
    valid_label = []
    valid_predicted = []
    
    for t in range(n_test_time_steps):
        for m in range(172):
            for n in range(63):
                for a in range(time_step_ahead):
                    if qa_arr[n_training_time_steps+t+a,m,n] == 0 and ndvi_arr[n_training_time_steps+t+a,m,n]>0 and study_region_mask[m,n] == 1:
                        valid_label.append(labeled_data[t,m,n,a])
                        valid_predicted.append(predicted[t,m,n,a])
                        
    print("R squared is: "+str(sklearn.metrics.r2_score(valid_label,valid_predicted)))
    print("RMSE is: "+str(mean_squared_error(valid_label,valid_predicted, squared=False)))

# %%
test_data_label=test_data_label[:,-1,:,:,:]
print(test_data_label.shape)
evaluate_method_performance(test_data_label, predicted,initial_ndvi.shape[0])
# Out:
# (178, 172, 63, 23)
# R squared is: 0.37643949352649386
# RMSE is: 0.10260794175085622

# %%
# Visualize the predictions of 12 pixels
time_steps = range(training_size+1, training_size+1+len(test_data_label))

fig, axes = plt.subplots(3,4, figsize=(22,14))
fig.tight_layout(pad=4.0)
for i in range(1,13):
    #for j in range(1,3):

    plt.subplot(3,4,i)

    pixel_y = random.randint(0,ndvi.height-1)
    pixel_x = random.randint(0,ndvi.width-1)

    while study_region_mask[pixel_y,pixel_x] == -1:
        pixel_y = random.randint(0,ndvi.height-1)
        pixel_x = random.randint(0,ndvi.width-1)

    true_series = test_data_label[:,pixel_y,pixel_x,-1]   
    predict_series = predicted[:,pixel_y,pixel_x,-1]
    plt.plot(time_steps, true_series,"b-", label='True')
    plt.plot(time_steps, predict_series,"r--", label='Predicted')
    #plt.ylim(0.0,1.0)
    plt.xlabel("Time Steps")
    plt.ylabel("NDVI")
    plt.legend()
    plt.grid('on')
    plt.title('Pixel at row:'+str(pixel_y)+" column:"+str(pixel_x))

# %%
predicted_reshape = predicted

# %%
# calculate per pixel rmse

spatial_rmse = np.random.rand(ndvi.height,ndvi.width)

for i in range(ndvi.height):
    for j in range(ndvi.width):
        this_true = test_data_label[:,i,j,-1]
        this_predict = predicted_reshape[:,i,j,-1]
        this_rmse = mean_squared_error(this_true,this_predict, squared=False)

        spatial_rmse[i,j] = this_rmse

spatial_rmse_masked = np.empty(shape=np.shape(covariates_arr))

spatial_rmse_masked = mask_layer(spatial_rmse,study_region_mask)


for m in range(172):
    for n in range(63):
        if spatial_rmse_masked[m,n] == 0:
            spatial_rmse_masked[m,n] = np.nan
        else:
            pass
import matplotlib
norm = matplotlib.colors.Normalize(vmin=0, vmax=0.35) 
plt.figure(figsize=(5,10))
plt.title("spatial RMSE of FC-LSTM")
plt.imshow(spatial_rmse_masked, cmap="Greys_r", norm=norm)
plt.colorbar()
plt.axis("off")
#plt.savefig("spatial RMSE of RNN new.png", dpi = 1320)

# %%
n_steps = 15
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$", legend=True):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bo", label="Target")
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "rx", markersize=10, label="Prediction")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])
    if legend and (y or y_pred):
        plt.legend(fontsize=14, loc="upper left")

# %%
test_data_input = test_data_input.reshape((test_data_label.shape[0],15,172,63,1))

# %%
fig, axes = plt.subplots(3,4, figsize=(22,14))
fig.tight_layout(pad=4.0)
for i in range(1,13):
    #for j in range(1,3):

    plt.subplot(3,4,i)

    pixel_y = random.randint(0,ndvi.height-1)
    pixel_x = random.randint(0,ndvi.width-1)

    while study_region_mask[pixel_y,pixel_x] == -1:
        pixel_y = random.randint(0,ndvi.height-1)
        pixel_x = random.randint(0,ndvi.width-1)


    random_step = random.randint(0,test_data_label.shape[0])
    true_series = test_data_label[:,pixel_y,pixel_x,-1]   
    predict_series = predicted[:,pixel_y,pixel_x,-1]
    ahead = step_ahead
    plot_series(test_data_input[random_step,:,pixel_y, pixel_x, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), test_data_label[random_step,pixel_y, pixel_x,:], "bo-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), predicted[random_step,pixel_y, pixel_x,:], "rx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)
    plt.title("time step:" +str(random_step+initial_ndvi.shape[0])+" row: " + str(pixel_y) + " column: " + str(pixel_x))
